# %%
# Install required libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import optuna
import warnings
from datetime import datetime
import os
import hashlib
import sys
import re

warnings.filterwarnings('ignore')

# Print environment and library versions for debugging
print(f"Python version: {sys.version}")
print(f"XGBoost version: {xgb.__version__}")
print(f"Optuna version: {optuna.__version__}")
print(f"LightGBM version: {lgb.__version__}")

# Robust XGBoost version check
def get_xgboost_major_version():
    try:
        version = xgb.__version__
        match = re.match(r"(\d+)\.", version)
        if match:
            return int(match.group(1))
        return 1  # Default to 1 if version parsing fails
    except:
        return 1  # Fallback for corrupted installation

xgb_major_version = get_xgboost_major_version()
print(f"Parsed XGBoost major version: {xgb_major_version}")

# For reproducibility
np.random.seed(42)

# Print current timestamp to confirm fresh run
print(f"Script started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# Load data
try:
    train = pd.read_csv('train.csv')
    test = pd.read_csv('test.csv')
    sample = pd.read_csv('sample_submission.csv')
except FileNotFoundError:
    print("Error: Ensure train.csv, test.csv, and sample_submission.csv are in the working directory.")
    exit()

print(f'Train shape: {train.shape}')
print(f'Test shape: {test.shape}')
print(f'Sample shape: {sample.shape}')
print(f'Train columns: {train.columns.tolist()}')
print('Column data types:')
print(train.dtypes)
print('Missing values in train:')
print(train.isnull().sum())
print('Missing values in test:')
print(test.isnull().sum())

# Check target distribution
y = train['accident_risk']
print(f'Target skewness: {y.skew():.3f}')
print(f'Target min: {y.min():.3f}, max: {y.max():.3f}, mean: {y.mean():.3f}')
plt.hist(y, bins=30)
plt.title('Distribution of accident_risk')
plt.show()

# Check for zero or negative targets
zero_risk = (y == 0).sum()
negative_risk = (y < 0).sum()
print(f'Zero risk rows: {zero_risk}')
print(f'Negative risk rows: {negative_risk}')

# Validate columns
required_cols = ['id', 'accident_risk', 'speed_limit', 'curvature', 'road_type', 
                 'lighting', 'weather', 'time_of_day', 'road_signs_present', 
                 'public_road', 'holiday', 'school_season']
missing_cols = [col for col in required_cols if col not in train.columns]
if missing_cols:
    print(f"Error: Missing columns in train: {missing_cols}")
    exit()

# Preprocessing
# Drop id
train_id = train['id']
test_id = test['id']
train = train.drop('id', axis=1)
test = test.drop('id', axis=1)

# Target (log-transform if skewed)
use_log_transform = y.skew() > 1 or y.skew() < -1
if use_log_transform:
    print('Applying log1p transformation to target due to skewness.')
    y = np.log1p(y)

train = train.drop('accident_risk', axis=1)

# Combine for preprocessing
all_data = pd.concat([train, test], axis=0, ignore_index=True)

# Feature engineering
all_data['speed_curv_interact'] = all_data['speed_limit'] * all_data['curvature']
all_data['bad_weather'] = np.where(all_data['weather'].isin(['rainy', 'foggy']), 1, 0)
all_data['poor_lighting'] = np.where(all_data['lighting'].isin(['dim', 'night']), 1, 0)
all_data['rush_hour'] = np.where(all_data['time_of_day'].isin(['morning', 'evening']), 1, 0)
all_data['road_condition'] = all_data['curvature'] * all_data['bad_weather']
all_data['speed_weather_interact'] = all_data['speed_limit'] * all_data['bad_weather']
all_data['curvature_lighting'] = all_data['curvature'] * all_data['poor_lighting']

# Encode categoricals
cat_cols = ['road_type', 'lighting', 'weather', 'time_of_day']
label_encoders = {}
for col in cat_cols:
    all_data[col] = all_data[col].astype(str)
    le = LabelEncoder()
    all_data[col] = le.fit_transform(all_data[col])
    label_encoders[col] = le

# Boolean cols to int
bool_cols = ['road_signs_present', 'public_road', 'holiday', 'school_season']
for col in bool_cols:
    all_data[col] = all_data[col].astype(int)

# Handle outliers
num_cols = ['speed_limit', 'curvature', 'speed_curv_interact', 'road_condition', 
            'speed_weather_interact', 'curvature_lighting']
for col in num_cols:
    upper_limit = all_data[col].quantile(0.99)
    all_data[col] = np.clip(all_data[col], None, upper_limit)

# Data integrity checks for numeric columns
numeric_cols = all_data.select_dtypes(include=[np.number]).columns
if all_data[numeric_cols].isna().any().any():
    print("Warning: NaNs found in numeric columns. Filling with median.")
    all_data[numeric_cols] = all_data[numeric_cols].fillna(all_data[numeric_cols].median())
if np.isinf(all_data[numeric_cols].values).any():
    print("Warning: Infinities found in numeric columns. Replacing with max/min values.")
    all_data[numeric_cols] = all_data[numeric_cols].replace([np.inf, -np.inf], 
                                                            [all_data[numeric_cols].max().max(), 
                                                             all_data[numeric_cols].min().min()])

# Split back
train = all_data[:len(train)].reset_index(drop=True)
test = all_data[len(train):].reset_index(drop=True)

# Prepare X
X = train
X_test = test

print('Preprocessing complete.')

# Optuna objective for LightGBM
def lgbm_objective(trial, X_train, y_train, X_val, y_val, use_log_transform):
    params = {
        'objective': 'regression',
        'metric': 'rmse',
        'verbosity': -1,
        'n_jobs': -1,
        'random_state': 42,
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.02, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 500, 2000),
        'num_leaves': trial.suggest_int('num_leaves', 20, 50),
        'max_depth': trial.suggest_int('max_depth', 5, 10),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 40),
        'subsample': trial.suggest_float('subsample', 0.7, 0.9),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.7, 0.9)
    }
    try:
        model = lgb.LGBMRegressor(**params)
        model.fit(
            X_train, y_train,
            eval_set=[(X_val, y_val)],
            eval_metric='rmse',
            callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=False)]
        )
        y_pred = model.predict(X_val)
        if use_log_transform:
            y_pred = np.expm1(y_pred)
            y_val = np.expm1(y_val)
        return np.sqrt(mean_squared_error(y_val, y_pred))
    except Exception as e:
        print(f"LightGBM trial failed: {e}")
        return float('inf')

# Optuna objective for XGBoost
def xgb_objective(trial, X_train, y_train, X_val, y_val, use_log_transform):
    params = {
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse',
        'n_jobs': -1,
        'random_state': 42,
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.02, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 500, 1500),
        'max_depth': trial.suggest_int('max_depth', 3, 8),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 5),
        'subsample': trial.suggest_float('subsample', 0.8, 0.95),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.8, 0.95)
    }
    try:
        model = xgb.XGBRegressor(**params)
        if xgb_major_version >= 2:
            model.fit(
                X_train, y_train,
                eval_set=[(X_val, y_val)],
                callbacks=[xgb.callback.EarlyStopping(rounds=100, save_best=True)],
                verbose=False
            )
        else:
            try:
                model.fit(
                    X_train, y_train,
                    eval_set=[(X_val, y_val)],
                    early_stopping_rounds=100,
                    verbose=False
                )
            except TypeError:
                print("Warning: XGBoost early stopping not supported. Training without early stopping.")
                model.fit(X_train, y_train, verbose=False)
        y_pred = model.predict(X_val)
        if use_log_transform:
            y_pred = np.expm1(y_pred)
            y_val = np.expm1(y_val)
        return np.sqrt(mean_squared_error(y_val, y_pred))
    except Exception as e:
        print(f"XGBoost trial failed: {e}")
        return float('inf')

# Cross-validation setup
kf = KFold(n_splits=5, shuffle=True, random_state=42)
lgbm_preds = np.zeros(len(X_test))
xgb_preds = np.zeros(len(X_test))
lgbm_only_preds = np.zeros(len(X_test))
oof_lgbm_preds = np.zeros(len(X))
oof_xgb_preds = np.zeros(len(X))
val_rmse = []
val_rmse_lgbm = []

# Ensemble weight tuning
weight_combinations = [
    (0.7, 0.3),  # lgbm, xgb
    (0.8, 0.2),
    (0.6, 0.4),
    (0.9, 0.1)
]

best_weights = None
best_val_rmse = float('inf')

# Cross-validation loop
for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    print(f'Training fold {fold + 1}...')
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    # LightGBM with Optuna
    lgbm_study = optuna.create_study(direction='minimize')
    lgbm_study.optimize(lambda trial: lgbm_objective(trial, X_train, y_train, X_val, y_val, use_log_transform), n_trials=10)
    lgbm_params = lgbm_study.best_params
    lgbm_params.update({
        'objective': 'regression',
        'metric': 'rmse',
        'verbosity': -1,
        'n_jobs': -1,
        'random_state': 42
    })
    lgbm_model = lgb.LGBMRegressor(**lgbm_params)
    lgbm_model.fit(
        X_train, y_train,
        eval_set=[(X_val, y_val)],
        eval_metric='rmse',
        callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=False)]
    )
    
    # XGBoost with Optuna
    xgb_study = optuna.create_study(direction='minimize')
    xgb_study.optimize(lambda trial: xgb_objective(trial, X_train, y_train, X_val, y_val, use_log_transform), n_trials=10)
    if not xgb_study.trials:
        print("Warning: No XGBoost trials completed. Using default parameters.")
        xgb_params = {
            'objective': 'reg:squarederror',
            'eval_metric': 'rmse',
            'n_jobs': -1,
            'random_state': 42,
            'learning_rate': 0.01,
            'n_estimators': 1000,
            'max_depth': 6,
            'min_child_weight': 1,
            'subsample': 0.8,
            'colsample_bytree': 0.8
        }
    else:
        xgb_params = xgb_study.best_params
    xgb_params.update({
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse',
        'n_jobs': -1,
        'random_state': 42
    })
    xgb_model = xgb.XGBRegressor(**xgb_params)
    try:
        if xgb_major_version >= 2:
            xgb_model.fit(
                X_train, y_train,
                eval_set=[(X_val, y_val)],
                callbacks=[xgb.callback.EarlyStopping(rounds=100, save_best=True)],
                verbose=False
            )
        else:
            xgb_model.fit(
                X_train, y_train,
                eval_set=[(X_val, y_val)],
                early_stopping_rounds=100,
                verbose=False
            )
    except TypeError:
        print("Warning: XGBoost early stopping not supported. Training without early stopping.")
        xgb_model.fit(X_train, y_train, verbose=False)
    
    # Validation predictions
    lgbm_val_pred = lgbm_model.predict(X_val)
    xgb_val_pred = xgb_model.predict(X_val)
    
    # Save OOF predictions
    oof_lgbm_preds[val_idx] = lgbm_val_pred
    oof_xgb_preds[val_idx] = xgb_val_pred
    
    # Tune ensemble weights
    fold_best_rmse = float('inf')
    fold_best_weights = None
    for w_lgbm, w_xgb in weight_combinations:
        val_pred = w_lgbm * lgbm_val_pred + w_xgb * xgb_val_pred
        if use_log_transform:
            val_pred = np.expm1(val_pred)
            y_val_temp = np.expm1(y_val)
        else:
            y_val_temp = y_val
        rmse = np.sqrt(mean_squared_error(y_val_temp, val_pred))
        if rmse < fold_best_rmse:
            fold_best_rmse = rmse
            fold_best_weights = (w_lgbm, w_xgb)
    
    val_rmse.append(fold_best_rmse)
    print(f'Fold {fold + 1} RMSE (ensemble): {fold_best_rmse:.5f} with weights {fold_best_weights}')
    
    # LightGBM-only validation RMSE
    lgbm_val_rmse = np.sqrt(mean_squared_error(np.expm1(y_val) if use_log_transform else y_val, 
                                               np.expm1(lgbm_val_pred) if use_log_transform else lgbm_val_pred))
    val_rmse_lgbm.append(lgbm_val_rmse)
    print(f'Fold {fold + 1} RMSE (LightGBM only): {lgbm_val_rmse:.5f}')
    
    # Test predictions
    lgbm_preds += lgbm_model.predict(X_test) / kf.n_splits
    xgb_preds += xgb_model.predict(X_test) / kf.n_splits
    lgbm_only_preds += lgbm_model.predict(X_test) / kf.n_splits
    
    # Update global best weights
    if fold_best_rmse < best_val_rmse:
        best_val_rmse = fold_best_rmse
        best_weights = fold_best_weights

# Stack test predictions
test_preds = best_weights[0] * lgbm_preds + best_weights[1] * xgb_preds
if use_log_transform:
    test_preds = np.expm1(test_preds)
lgbm_only_test_preds = np.expm1(lgbm_only_preds) if use_log_transform else lgbm_only_preds

# Ensure predictions are between 0 and 1
test_preds = np.clip(test_preds, 0.01, 0.99)
lgbm_only_test_preds = np.clip(lgbm_only_test_preds, 0.01, 0.99)

# Additional prediction validation
print(f'Ensemble test predictions min: {test_preds.min():.3f}, max: {test_preds.max():.3f}, mean: {test_preds.mean():.3f}')
print(f'LightGBM-only test predictions min: {lgbm_only_test_preds.min():.3f}, max: {lgbm_only_test_preds.max():.3f}, mean: {lgbm_only_test_preds.mean():.3f}')

print(f'Mean CV RMSE (ensemble): {np.mean(val_rmse):.5f} ± {np.std(val_rmse):.5f}')
print(f'Mean CV RMSE (LightGBM only): {np.mean(val_rmse_lgbm):.5f} ± {np.std(val_rmse_lgbm):.5f}')
print(f'Best ensemble weights: {best_weights}')

# Feature importance
lgb.plot_importance(lgbm_model, max_num_features=10)
plt.title('LightGBM Feature Importance')
plt.show()

# Feature selection: Identify low-importance features
importances = pd.Series(lgbm_model.feature_importances_, index=X.columns)
low_importance = importances[importances < importances.mean() * 0.5].index.tolist()
print(f'Low-importance features: {low_importance}')

# Save OOF predictions for future stacking
oof_df = pd.DataFrame({
    'id': train_id,
    'oof_lgbm_pred': np.expm1(oof_lgbm_preds) if use_log_transform else oof_lgbm_preds,
    'oof_xgb_pred': np.expm1(oof_xgb_preds) if use_log_transform else oof_xgb_preds
})
oof_df.to_csv('oof_preds_lgbm_xgb_v21.csv', index=False)
print(f'OOF predictions saved as oof_preds_lgbm_xgb_v21.csv')

# Submission (ensemble)
submission = pd.DataFrame({'id': test_id, 'accident_risk': test_preds})
submission_file = 'submission_lgbm_xgb_v21.csv'
submission.to_csv(submission_file, index=False)
print(f'Ensemble submission saved as {submission_file} at {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}')
print('Ensemble submission summary:')
print(submission.describe())
print('Ensemble submission preview (first 10 rows):')
print(submission.head(10))

# Submission (LightGBM only)
submission_lgbm = pd.DataFrame({'id': test_id, 'accident_risk': lgbm_only_test_preds})
submission_file_lgbm = 'submission_lgbm_v21.csv'
submission_lgbm.to_csv(submission_file_lgbm, index=False)
print(f'LightGBM-only submission saved as {submission_file_lgbm} at {datetime.now().strftime("%Y-%m-%d %H:%M:%S")}')
print('LightGBM-only submission summary:')
print(submission_lgbm.describe())
print('LightGBM-only submission preview (first 10 rows):')
print(submission_lgbm.head(10))

# Calculate file hashes
for file in [submission_file, submission_file_lgbm, 'oof_preds_lgbm_xgb_v21.csv']:
    if os.path.exists(file):
        with open(file, 'rb') as f:
            file_hash = hashlib.md5(f.read()).hexdigest()
        file_size = os.path.getsize(file) / 1024  # Size in KB
        print(f'{file} size: {file_size:.2f} KB')
        print(f'{file} MD5 hash: {file_hash}')
    else:
        print(f"Error: {file} was not created.")

# Validate submission format
for submission_df, file in [(submission, submission_file), (submission_lgbm, submission_file_lgbm)]:
    if not all(submission_df.columns == ['id', 'accident_risk']):
        print(f"Error: {file} must have columns 'id' and 'accident_risk'.")
    if len(submission_df) != len(sample):
        print(f"Error: {file} has {len(submission_df)} rows, expected {len(sample)}.")
    if not submission_df['id'].equals(sample['id']):
        print(f"Error: {file} 'id' column does not match sample_submission.csv.")

# Debug: Save raw test predictions
raw_preds = pd.DataFrame({'id': test_id, 'ensemble_pred': test_preds, 'lgbm_pred': lgbm_only_test_preds})
raw_preds.to_csv('raw_test_preds_lgbm_xgb_v21.csv', index=False)
print(f'Raw test predictions saved as raw_test_preds_lgbm_xgb_v21.csv')
# Out:
# Python version: 3.13.3 (tags/v3.13.3:6280bb5, Apr  8 2025, 14:47:33) [MSC v.1943 64 bit (AMD64)]
# XGBoost version: 3.0.5
# Optuna version: 4.5.0
# LightGBM version: 4.6.0
# Parsed XGBoost major version: 3
# Script started at: 2025-10-09 22:16:26
# Train shape: (517754, 14)
# Test shape: (172585, 13)
# Sample shape: (172585, 2)
# Train columns: ['id', 'road_type', 'num_lanes', 'curvature', 'speed_limit', 'lighting', 'weather', 'road_signs_present', 'public_road', 'time_of_day', 'holiday', 'school_season', 'num_reported_accidents', 'accident_risk']
# Column data types:
# id                          int64
# road_type                  object
# num_lanes                   int64
# curvature                 float64
# speed_limit                 int64
# lighting                   object
# weather                    object
# road_signs_present           bool
# public_road                  bool
# time_of_day                object
# holiday                      bool
# school_season                bool
# num_reported_accidents      int64
# accident_risk             float64
# dtype: object
# Missing values in train:
# id                        0
# road_type                 0
# num_lanes                 0
# curvature                 0
# speed_limit               0
# lighting                  0
# weather                   0
# road_signs_present        0
# public_road               0
# time_of_day               0
# holiday                   0
# school_season             0
# num_reported_accidents    0
# accident_risk             0
# dtype: int64
# Missing values in test:
# id                        0
# road_type                 0
# num_lanes                 0
# curvature                 0
# speed_limit               0
# lighting                  0
# weather                   0
# road_signs_present        0
# public_road               0
# time_of_day               0
# holiday                   0
# school_season             0
# num_reported_accidents    0
# dtype: int64
# Target skewness: 0.378
# Target min: 0.000, max: 1.000, mean: 0.352
# Zero risk rows: 608
# Negative risk rows: 0
# [I 2025-10-09 22:16:30,835] A new study created in memory with name: no-name-669dfbfd-c14d-4f14-b085-8251937d0382
# Preprocessing complete.
# Training fold 1...
# [I 2025-10-09 22:16:52,680] Trial 0 finished with value: 0.05634910528011365 and parameters: {'learning_rate': 0.007130878840972189, 'n_estimators': 1107, 'num_leaves': 48, 'max_depth': 7, 'min_data_in_leaf': 23, 'subsample': 0.8661170715561124, 'colsample_bytree': 0.7612766373356583}. Best is trial 0 with value: 0.05634910528011365.
# [I 2025-10-09 22:17:11,908] Trial 1 finished with value: 0.056365132091439854 and parameters: {'learning_rate': 0.007745685605522735, 'n_estimators': 1124, 'num_leaves': 44, 'max_depth': 9, 'min_data_in_leaf': 36, 'subsample': 0.8106166531506891, 'colsample_bytree': 0.8908963168655386}. Best is trial 0 with value: 0.05634910528011365.
# [I 2025-10-09 22:17:21,977] Trial 2 finished with value: 0.05655936049715328 and parameters: {'learning_rate': 0.012305149728009179, 'n_estimators': 804, 'num_leaves': 21, 'max_depth': 9, 'min_data_in_leaf': 25, 'subsample': 0.8824984279255812, 'colsample_bytree': 0.8479282282137386}. Best is trial 0 with value: 0.05634910528011365.
# [I 2025-10-09 22:17:36,129] Trial 3 finished with value: 0.05651671134846126 and parameters: {'learning_rate': 0.007247785597488324, 'n_estimators': 985, 'num_leaves': 28, 'max_depth': 7, 'min_data_in_leaf': 28, 'subsample': 0.8262635628353949, 'colsample_bytree': 0.7481666361901362}. Best is trial 0 with value: 0.05634910528011365.
# [I 2025-10-09 22:17:49,519] Trial 4 finished with value: 0.05633828778962389 and parameters: {'learning_rate': 0.01383057700524598, 'n_estimators': 892, 'num_leaves': 39, 'max_depth': 7, 'min_data_in_leaf': 22, 'subsample': 0.7609163094998722, 'colsample_bytree': 0.7359031990459962}. Best is trial 4 with value: 0.05633828778962389.
# [I 2025-10-09 22:17:58,598] Trial 5 finished with value: 0.05636440501664466 and parameters: {'learning_rate': 0.01712213121155318, 'n_estimators': 587, 'num_leaves': 39, 'max_depth': 7, 'min_data_in_leaf': 21, 'subsample': 0.8476024980396366, 'colsample_bytree': 0.7366657716893888}. Best is trial 4 with value: 0.05633828778962389.
# [I 2025-10-09 22:18:22,677] Trial 6 finished with value: 0.05628518762593823 and parameters: {'learning_rate': 0.008596323616467247, 'n_estimators': 1612, 'num_leaves': 46, 'max_depth': 7, 'min_data_in_leaf': 11, 'subsample': 0.8641294811793421, 'colsample_bytree': 0.7163358479502417}. Best is trial 6 with value: 0.05628518762593823.
# [I 2025-10-09 22:18:37,388] Trial 7 finished with value: 0.05648703670549346 and parameters: {'learning_rate': 0.007860569089899419, 'n_estimators': 1125, 'num_leaves': 39, 'max_depth': 5, 'min_data_in_leaf': 20, 'subsample': 0.834403208056788, 'colsample_bytree': 0.7508644776484954}. Best is trial 6 with value: 0.05628518762593823.
# [I 2025-10-09 22:19:04,018] Trial 8 finished with value: 0.05631135639242726 and parameters: {'learning_rate': 0.007054114392629103, 'n_estimators': 1690, 'num_leaves': 45, 'max_depth': 8, 'min_data_in_leaf': 32, 'subsample': 0.7731704055990496, 'colsample_bytree': 0.7375659871143911}. Best is trial 6 with value: 0.05628518762593823.
# [I 2025-10-09 22:19:15,831] Trial 9 finished with value: 0.056448207770890386 and parameters: {'learning_rate': 0.010924575439878941, 'n_estimators': 824, 'num_leaves': 30, 'max_depth': 10, 'min_data_in_leaf': 34, 'subsample': 0.8097729337467791, 'colsample_bytree': 0.7616495686418453}. Best is trial 6 with value: 0.05628518762593823.
# [I 2025-10-09 22:19:37,204] A new study created in memory with name: no-name-458a308c-b240-46ab-be73-f0030b406bea
# [I 2025-10-09 22:19:37,210] Trial 0 finished with value: inf and parameters: {'learning_rate': 0.007651054172844417, 'n_estimators': 1097, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.8521456997187802, 'colsample_bytree': 0.9243219849373308}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:19:37,213] Trial 1 finished with value: inf and parameters: {'learning_rate': 0.008034564971382996, 'n_estimators': 651, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.828588268996382, 'colsample_bytree': 0.9441281659784708}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:19:37,216] Trial 2 finished with value: inf and parameters: {'learning_rate': 0.005770658519583983, 'n_estimators': 555, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.926296689929747, 'colsample_bytree': 0.9407024692607568}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:19:37,220] Trial 3 finished with value: inf and parameters: {'learning_rate': 0.014442437372502621, 'n_estimators': 641, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.8560787841084265, 'colsample_bytree': 0.9054406799092863}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:19:37,224] Trial 4 finished with value: inf and parameters: {'learning_rate': 0.009729744652864936, 'n_estimators': 1139, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9185420720101503, 'colsample_bytree': 0.8653527988450828}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:19:37,227] Trial 5 finished with value: inf and parameters: {'learning_rate': 0.010835908654516708, 'n_estimators': 1113, 'max_depth': 8, 'min_child_weight': 2, 'subsample': 0.9088977338495313, 'colsample_bytree': 0.8093628212665118}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:19:37,231] Trial 6 finished with value: inf and parameters: {'learning_rate': 0.010229218042920624, 'n_estimators': 529, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.8809029594461617, 'colsample_bytree': 0.8067729631700398}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:19:37,234] Trial 7 finished with value: inf and parameters: {'learning_rate': 0.008435679848472495, 'n_estimators': 862, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.9373283376244723, 'colsample_bytree': 0.9001428258707845}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:19:37,238] Trial 8 finished with value: inf and parameters: {'learning_rate': 0.005363948612547715, 'n_estimators': 527, 'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.8296232927563258, 'colsample_bytree': 0.8451074220441994}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:19:37,242] Trial 9 finished with value: inf and parameters: {'learning_rate': 0.010236768798517395, 'n_estimators': 551, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.8556333103421881, 'colsample_bytree': 0.8315058051528672}. Best is trial 0 with value: inf.
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# Warning: XGBoost early stopping not supported. Training without early stopping.
# Fold 1 RMSE (ensemble): 0.05628 with weights (0.7, 0.3)
# Fold 1 RMSE (LightGBM only): 0.05629
# [I 2025-10-09 22:20:03,707] A new study created in memory with name: no-name-f6ba71d4-45bf-4bbd-bdb1-1c38264d736f
# Training fold 2...
# [I 2025-10-09 22:20:13,174] Trial 0 finished with value: 0.05626199440814717 and parameters: {'learning_rate': 0.01894940523032182, 'n_estimators': 677, 'num_leaves': 25, 'max_depth': 8, 'min_data_in_leaf': 34, 'subsample': 0.7840688487001394, 'colsample_bytree': 0.856147855809206}. Best is trial 0 with value: 0.05626199440814717.
# [I 2025-10-09 22:20:25,550] Trial 1 finished with value: 0.05620645030807685 and parameters: {'learning_rate': 0.013416061994468998, 'n_estimators': 835, 'num_leaves': 37, 'max_depth': 9, 'min_data_in_leaf': 18, 'subsample': 0.8096874270349821, 'colsample_bytree': 0.718163418612063}. Best is trial 1 with value: 0.05620645030807685.
# [I 2025-10-09 22:20:43,217] Trial 2 finished with value: 0.05623257939714071 and parameters: {'learning_rate': 0.008712001902370557, 'n_estimators': 1284, 'num_leaves': 30, 'max_depth': 10, 'min_data_in_leaf': 24, 'subsample': 0.8153417858287417, 'colsample_bytree': 0.7479021644070727}. Best is trial 1 with value: 0.05620645030807685.
# [I 2025-10-09 22:21:02,659] Trial 3 finished with value: 0.05631168971550965 and parameters: {'learning_rate': 0.0065909262409074194, 'n_estimators': 1467, 'num_leaves': 40, 'max_depth': 5, 'min_data_in_leaf': 33, 'subsample': 0.7054920122871888, 'colsample_bytree': 0.7705667012573174}. Best is trial 1 with value: 0.05620645030807685.
# [I 2025-10-09 22:21:17,299] Trial 4 finished with value: 0.056230610868823715 and parameters: {'learning_rate': 0.01472929323043651, 'n_estimators': 1285, 'num_leaves': 24, 'max_depth': 6, 'min_data_in_leaf': 37, 'subsample': 0.7518097165614254, 'colsample_bytree': 0.7433599770117572}. Best is trial 1 with value: 0.05620645030807685.
# [I 2025-10-09 22:21:39,959] Trial 5 finished with value: 0.056174818313148224 and parameters: {'learning_rate': 0.010799062360646986, 'n_estimators': 1882, 'num_leaves': 45, 'max_depth': 5, 'min_data_in_leaf': 26, 'subsample': 0.8099960944572948, 'colsample_bytree': 0.7069479621064083}. Best is trial 5 with value: 0.056174818313148224.
# [I 2025-10-09 22:22:02,778] Trial 6 finished with value: 0.0561663023988775 and parameters: {'learning_rate': 0.010923181768171258, 'n_estimators': 1907, 'num_leaves': 44, 'max_depth': 5, 'min_data_in_leaf': 22, 'subsample': 0.7743151834841386, 'colsample_bytree': 0.811204250319165}. Best is trial 6 with value: 0.0561663023988775.
# [I 2025-10-09 22:22:14,133] Trial 7 finished with value: 0.056195873790192696 and parameters: {'learning_rate': 0.014726306767097042, 'n_estimators': 691, 'num_leaves': 44, 'max_depth': 8, 'min_data_in_leaf': 19, 'subsample': 0.8203125344020967, 'colsample_bytree': 0.8088611023230166}. Best is trial 6 with value: 0.0561663023988775.
# [I 2025-10-09 22:22:25,434] Trial 8 finished with value: 0.0561676199620086 and parameters: {'learning_rate': 0.0182255525479966, 'n_estimators': 851, 'num_leaves': 35, 'max_depth': 9, 'min_data_in_leaf': 12, 'subsample': 0.7673444126859296, 'colsample_bytree': 0.8005713097920351}. Best is trial 6 with value: 0.0561663023988775.
# [I 2025-10-09 22:22:39,024] Trial 9 finished with value: 0.056218348253335264 and parameters: {'learning_rate': 0.010845291018510058, 'n_estimators': 969, 'num_leaves': 33, 'max_depth': 7, 'min_data_in_leaf': 12, 'subsample': 0.8065334034778067, 'colsample_bytree': 0.8414197435726773}. Best is trial 6 with value: 0.0561663023988775.
# [I 2025-10-09 22:23:00,332] A new study created in memory with name: no-name-44ea0450-a530-4275-8406-513398899531
# [I 2025-10-09 22:23:00,338] Trial 0 finished with value: inf and parameters: {'learning_rate': 0.008044316472701757, 'n_estimators': 654, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.8817285493142004, 'colsample_bytree': 0.9304198864369073}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:23:00,340] Trial 1 finished with value: inf and parameters: {'learning_rate': 0.017233032014618312, 'n_estimators': 656, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.851815325896804, 'colsample_bytree': 0.9181072828802425}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:23:00,344] Trial 2 finished with value: inf and parameters: {'learning_rate': 0.01583647123919237, 'n_estimators': 1016, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8185146423741324, 'colsample_bytree': 0.810336235952382}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:23:00,347] Trial 3 finished with value: inf and parameters: {'learning_rate': 0.01654914587583583, 'n_estimators': 781, 'max_depth': 3, 'min_child_weight': 5, 'subsample': 0.834025944467771, 'colsample_bytree': 0.8040964300168597}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:23:00,351] Trial 4 finished with value: inf and parameters: {'learning_rate': 0.006050777921762063, 'n_estimators': 638, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.8200537951667944, 'colsample_bytree': 0.9413485444252478}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:23:00,354] Trial 5 finished with value: inf and parameters: {'learning_rate': 0.006244885490631246, 'n_estimators': 893, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.8716456875416578, 'colsample_bytree': 0.8210319470878911}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:23:00,358] Trial 6 finished with value: inf and parameters: {'learning_rate': 0.010964068934015326, 'n_estimators': 831, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9192852354575158, 'colsample_bytree': 0.8659864144481826}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:23:00,361] Trial 7 finished with value: inf and parameters: {'learning_rate': 0.018060652949336058, 'n_estimators': 781, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8502604347396502, 'colsample_bytree': 0.8179751937951324}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:23:00,365] Trial 8 finished with value: inf and parameters: {'learning_rate': 0.006914654173740159, 'n_estimators': 1263, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8435709972677528, 'colsample_bytree': 0.8960700461107965}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:23:00,369] Trial 9 finished with value: inf and parameters: {'learning_rate': 0.009712962606268596, 'n_estimators': 707, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.8530921529066552, 'colsample_bytree': 0.8854384437457434}. Best is trial 0 with value: inf.
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# Warning: XGBoost early stopping not supported. Training without early stopping.
# Fold 2 RMSE (ensemble): 0.05616 with weights (0.8, 0.2)
# Fold 2 RMSE (LightGBM only): 0.05617
# [I 2025-10-09 22:23:24,172] A new study created in memory with name: no-name-4b15e081-03eb-42ea-8a41-10703b1448de
# Training fold 3...
# [I 2025-10-09 22:23:41,150] Trial 0 finished with value: 0.05624505210093738 and parameters: {'learning_rate': 0.01002355213732392, 'n_estimators': 908, 'num_leaves': 40, 'max_depth': 9, 'min_data_in_leaf': 17, 'subsample': 0.7288101390588063, 'colsample_bytree': 0.8634218147815449}. Best is trial 0 with value: 0.05624505210093738.
# [I 2025-10-09 22:23:53,340] Trial 1 finished with value: 0.05626777827307312 and parameters: {'learning_rate': 0.013159409941349887, 'n_estimators': 603, 'num_leaves': 41, 'max_depth': 7, 'min_data_in_leaf': 17, 'subsample': 0.8647039609686904, 'colsample_bytree': 0.7406790583375608}. Best is trial 0 with value: 0.05624505210093738.
# [I 2025-10-09 22:24:25,423] Trial 2 finished with value: 0.05624120600944108 and parameters: {'learning_rate': 0.0052940930080606205, 'n_estimators': 1656, 'num_leaves': 49, 'max_depth': 6, 'min_data_in_leaf': 39, 'subsample': 0.8754115841408202, 'colsample_bytree': 0.8062418342872208}. Best is trial 2 with value: 0.05624120600944108.
# [I 2025-10-09 22:24:42,113] Trial 3 finished with value: 0.05623415882395748 and parameters: {'learning_rate': 0.017882145153575946, 'n_estimators': 1325, 'num_leaves': 21, 'max_depth': 9, 'min_data_in_leaf': 33, 'subsample': 0.7645618500682604, 'colsample_bytree': 0.8902414423640879}. Best is trial 3 with value: 0.05623415882395748.
# [I 2025-10-09 22:25:12,257] Trial 4 finished with value: 0.05616948631136118 and parameters: {'learning_rate': 0.010958710299428116, 'n_estimators': 1861, 'num_leaves': 45, 'max_depth': 6, 'min_data_in_leaf': 19, 'subsample': 0.7952765320630609, 'colsample_bytree': 0.8565883638616029}. Best is trial 4 with value: 0.05616948631136118.
# [I 2025-10-09 22:25:26,942] Trial 5 finished with value: 0.056856559443720485 and parameters: {'learning_rate': 0.005118208634576259, 'n_estimators': 937, 'num_leaves': 21, 'max_depth': 8, 'min_data_in_leaf': 31, 'subsample': 0.8212185596791652, 'colsample_bytree': 0.728465805005007}. Best is trial 4 with value: 0.05616948631136118.
# [I 2025-10-09 22:25:49,290] Trial 6 finished with value: 0.05629314612171942 and parameters: {'learning_rate': 0.0060276908914343955, 'n_estimators': 1160, 'num_leaves': 47, 'max_depth': 6, 'min_data_in_leaf': 18, 'subsample': 0.8456050804310715, 'colsample_bytree': 0.7482095807738653}. Best is trial 4 with value: 0.05616948631136118.
# [I 2025-10-09 22:26:03,818] Trial 7 finished with value: 0.05630349507633875 and parameters: {'learning_rate': 0.00989303049926173, 'n_estimators': 788, 'num_leaves': 33, 'max_depth': 9, 'min_data_in_leaf': 14, 'subsample': 0.897507987722148, 'colsample_bytree': 0.7074955899258237}. Best is trial 4 with value: 0.05616948631136118.
# [I 2025-10-09 22:26:32,118] Trial 8 finished with value: 0.05625393899108011 and parameters: {'learning_rate': 0.008238267478264444, 'n_estimators': 1815, 'num_leaves': 28, 'max_depth': 9, 'min_data_in_leaf': 21, 'subsample': 0.8426622696245407, 'colsample_bytree': 0.8775461448840038}. Best is trial 4 with value: 0.05616948631136118.
# [I 2025-10-09 22:26:59,684] Trial 9 finished with value: 0.05622163846042259 and parameters: {'learning_rate': 0.009818431360766672, 'n_estimators': 1714, 'num_leaves': 30, 'max_depth': 7, 'min_data_in_leaf': 20, 'subsample': 0.7949394516295966, 'colsample_bytree': 0.8635083392755659}. Best is trial 4 with value: 0.05616948631136118.
# [I 2025-10-09 22:27:29,596] A new study created in memory with name: no-name-42969185-6a72-421d-881f-0a3d791a68ee
# [I 2025-10-09 22:27:29,601] Trial 0 finished with value: inf and parameters: {'learning_rate': 0.007240882789088851, 'n_estimators': 1346, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.9339628946297645, 'colsample_bytree': 0.9422601081363144}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:27:29,604] Trial 1 finished with value: inf and parameters: {'learning_rate': 0.007990617366820487, 'n_estimators': 1017, 'max_depth': 4, 'min_child_weight': 4, 'subsample': 0.8468235905740137, 'colsample_bytree': 0.8386137161567877}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:27:29,608] Trial 2 finished with value: inf and parameters: {'learning_rate': 0.01130405100305818, 'n_estimators': 670, 'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.9395443142693986, 'colsample_bytree': 0.8365179336531259}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:27:29,613] Trial 3 finished with value: inf and parameters: {'learning_rate': 0.009364879809059591, 'n_estimators': 1421, 'max_depth': 3, 'min_child_weight': 2, 'subsample': 0.8997859496600176, 'colsample_bytree': 0.8153024650017608}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:27:29,617] Trial 4 finished with value: inf and parameters: {'learning_rate': 0.006415240000745599, 'n_estimators': 1025, 'max_depth': 3, 'min_child_weight': 1, 'subsample': 0.937528563229886, 'colsample_bytree': 0.8255411933463035}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:27:29,621] Trial 5 finished with value: inf and parameters: {'learning_rate': 0.014495885799429462, 'n_estimators': 698, 'max_depth': 7, 'min_child_weight': 5, 'subsample': 0.9372570797410285, 'colsample_bytree': 0.8480368961675917}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:27:29,625] Trial 6 finished with value: inf and parameters: {'learning_rate': 0.00545370998416664, 'n_estimators': 502, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.9179598278844601, 'colsample_bytree': 0.9328333846929714}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:27:29,629] Trial 7 finished with value: inf and parameters: {'learning_rate': 0.012510518309478578, 'n_estimators': 503, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.9292776440242703, 'colsample_bytree': 0.9003166291346323}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:27:29,633] Trial 8 finished with value: inf and parameters: {'learning_rate': 0.010552838979549273, 'n_estimators': 1123, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.8149885950332011, 'colsample_bytree': 0.8903002977976403}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:27:29,637] Trial 9 finished with value: inf and parameters: {'learning_rate': 0.01475123749803878, 'n_estimators': 605, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8792107155272407, 'colsample_bytree': 0.8673816488031878}. Best is trial 0 with value: inf.
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# Warning: XGBoost early stopping not supported. Training without early stopping.
# Fold 3 RMSE (ensemble): 0.05616 with weights (0.6, 0.4)
# Fold 3 RMSE (LightGBM only): 0.05617
# [I 2025-10-09 22:28:09,056] A new study created in memory with name: no-name-0e595084-51bb-4037-90b3-367463cc21fd
# Training fold 4...
# [I 2025-10-09 22:28:41,665] Trial 0 finished with value: 0.056006454308453614 and parameters: {'learning_rate': 0.011518949968150706, 'n_estimators': 1852, 'num_leaves': 45, 'max_depth': 6, 'min_data_in_leaf': 38, 'subsample': 0.8972373921207423, 'colsample_bytree': 0.7945199560178773}. Best is trial 0 with value: 0.056006454308453614.
# [I 2025-10-09 22:28:56,520] Trial 1 finished with value: 0.05615053131462932 and parameters: {'learning_rate': 0.013794268969958768, 'n_estimators': 922, 'num_leaves': 43, 'max_depth': 5, 'min_data_in_leaf': 40, 'subsample': 0.7779927637563622, 'colsample_bytree': 0.750504655708606}. Best is trial 0 with value: 0.056006454308453614.
# [I 2025-10-09 22:29:24,949] Trial 2 finished with value: 0.05612896991661814 and parameters: {'learning_rate': 0.008969012364513938, 'n_estimators': 1892, 'num_leaves': 25, 'max_depth': 5, 'min_data_in_leaf': 13, 'subsample': 0.8754779595498188, 'colsample_bytree': 0.7529095348458084}. Best is trial 0 with value: 0.056006454308453614.
# [I 2025-10-09 22:29:54,678] Trial 3 finished with value: 0.05608715939067503 and parameters: {'learning_rate': 0.00593633104820793, 'n_estimators': 1422, 'num_leaves': 45, 'max_depth': 7, 'min_data_in_leaf': 37, 'subsample': 0.7898372319514283, 'colsample_bytree': 0.8069397142961481}. Best is trial 0 with value: 0.056006454308453614.
# [I 2025-10-09 22:30:16,816] Trial 4 finished with value: 0.0561065133062619 and parameters: {'learning_rate': 0.010588336600469258, 'n_estimators': 1918, 'num_leaves': 21, 'max_depth': 8, 'min_data_in_leaf': 10, 'subsample': 0.8653805668301864, 'colsample_bytree': 0.8165220094911545}. Best is trial 0 with value: 0.056006454308453614.
# [I 2025-10-09 22:30:38,563] Trial 5 finished with value: 0.056269880645989 and parameters: {'learning_rate': 0.0051400056248870766, 'n_estimators': 1662, 'num_leaves': 22, 'max_depth': 8, 'min_data_in_leaf': 25, 'subsample': 0.8534692503089936, 'colsample_bytree': 0.7939682774284476}. Best is trial 0 with value: 0.056006454308453614.
# [I 2025-10-09 22:30:53,620] Trial 6 finished with value: 0.056413046302696335 and parameters: {'learning_rate': 0.005761763351626887, 'n_estimators': 767, 'num_leaves': 39, 'max_depth': 10, 'min_data_in_leaf': 38, 'subsample': 0.8428629692788219, 'colsample_bytree': 0.7991426056139914}. Best is trial 0 with value: 0.056006454308453614.
# [I 2025-10-09 22:31:12,508] Trial 7 finished with value: 0.056035385858775225 and parameters: {'learning_rate': 0.010861436043597706, 'n_estimators': 1250, 'num_leaves': 42, 'max_depth': 7, 'min_data_in_leaf': 16, 'subsample': 0.7570236692199216, 'colsample_bytree': 0.848362419979553}. Best is trial 0 with value: 0.056006454308453614.
# [I 2025-10-09 22:31:26,916] Trial 8 finished with value: 0.05608013532973224 and parameters: {'learning_rate': 0.011959618856447531, 'n_estimators': 871, 'num_leaves': 43, 'max_depth': 6, 'min_data_in_leaf': 15, 'subsample': 0.8311096765252326, 'colsample_bytree': 0.705339566591739}. Best is trial 0 with value: 0.056006454308453614.
# [I 2025-10-09 22:31:38,424] Trial 9 finished with value: 0.05614085845610213 and parameters: {'learning_rate': 0.016967095548913774, 'n_estimators': 1002, 'num_leaves': 22, 'max_depth': 7, 'min_data_in_leaf': 11, 'subsample': 0.7959736512834102, 'colsample_bytree': 0.7229970503966318}. Best is trial 0 with value: 0.056006454308453614.
# [I 2025-10-09 22:32:02,482] A new study created in memory with name: no-name-cc81eaca-1c79-4a23-8b4e-eae6d7826d72
# [I 2025-10-09 22:32:02,488] Trial 0 finished with value: inf and parameters: {'learning_rate': 0.019136163090172367, 'n_estimators': 1430, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.905180291418466, 'colsample_bytree': 0.8463562579508557}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:32:02,491] Trial 1 finished with value: inf and parameters: {'learning_rate': 0.00997659016070805, 'n_estimators': 1090, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.9275710638421264, 'colsample_bytree': 0.8754309463915835}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:32:02,494] Trial 2 finished with value: inf and parameters: {'learning_rate': 0.018261633332618807, 'n_estimators': 1403, 'max_depth': 6, 'min_child_weight': 1, 'subsample': 0.8325558511970019, 'colsample_bytree': 0.8845147972615771}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:32:02,497] Trial 3 finished with value: inf and parameters: {'learning_rate': 0.010388221558906268, 'n_estimators': 1482, 'max_depth': 7, 'min_child_weight': 3, 'subsample': 0.8443069408398692, 'colsample_bytree': 0.9329667733157726}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:32:02,501] Trial 4 finished with value: inf and parameters: {'learning_rate': 0.01543718844340455, 'n_estimators': 1142, 'max_depth': 5, 'min_child_weight': 1, 'subsample': 0.9090537346135893, 'colsample_bytree': 0.8410522039940269}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:32:02,504] Trial 5 finished with value: inf and parameters: {'learning_rate': 0.01177593137344365, 'n_estimators': 679, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.8873999880594642, 'colsample_bytree': 0.8055199083268925}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:32:02,507] Trial 6 finished with value: inf and parameters: {'learning_rate': 0.006189048079857791, 'n_estimators': 510, 'max_depth': 7, 'min_child_weight': 2, 'subsample': 0.8432006531365349, 'colsample_bytree': 0.858043082315919}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:32:02,511] Trial 7 finished with value: inf and parameters: {'learning_rate': 0.011396994577910647, 'n_estimators': 1085, 'max_depth': 8, 'min_child_weight': 3, 'subsample': 0.9451380145536741, 'colsample_bytree': 0.8296676773546635}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:32:02,515] Trial 8 finished with value: inf and parameters: {'learning_rate': 0.012129429389283852, 'n_estimators': 1480, 'max_depth': 6, 'min_child_weight': 4, 'subsample': 0.9203660042775156, 'colsample_bytree': 0.8306132229084949}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:32:02,518] Trial 9 finished with value: inf and parameters: {'learning_rate': 0.016962319750121944, 'n_estimators': 850, 'max_depth': 3, 'min_child_weight': 3, 'subsample': 0.8413544271125909, 'colsample_bytree': 0.8492739234023361}. Best is trial 0 with value: inf.
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# Warning: XGBoost early stopping not supported. Training without early stopping.
# Fold 4 RMSE (ensemble): 0.05595 with weights (0.6, 0.4)
# Fold 4 RMSE (LightGBM only): 0.05601
# [I 2025-10-09 22:33:08,405] A new study created in memory with name: no-name-da039f6b-4aea-4d33-a5da-d9566fc5a4d3
# Training fold 5...
# [I 2025-10-09 22:34:16,815] Trial 0 finished with value: 0.056019758941878155 and parameters: {'learning_rate': 0.013635020368726753, 'n_estimators': 996, 'num_leaves': 47, 'max_depth': 7, 'min_data_in_leaf': 34, 'subsample': 0.7847754362090503, 'colsample_bytree': 0.7531089786522539}. Best is trial 0 with value: 0.056019758941878155.
# [I 2025-10-09 22:35:49,857] Trial 1 finished with value: 0.05607229369064644 and parameters: {'learning_rate': 0.0112983009949037, 'n_estimators': 1447, 'num_leaves': 28, 'max_depth': 8, 'min_data_in_leaf': 25, 'subsample': 0.7165169130357744, 'colsample_bytree': 0.7225853055330269}. Best is trial 0 with value: 0.056019758941878155.
# [I 2025-10-09 22:38:04,083] Trial 2 finished with value: 0.05605978963955406 and parameters: {'learning_rate': 0.007834736901706585, 'n_estimators': 1980, 'num_leaves': 33, 'max_depth': 7, 'min_data_in_leaf': 35, 'subsample': 0.7792652486000959, 'colsample_bytree': 0.8319174700005807}. Best is trial 0 with value: 0.056019758941878155.
# [I 2025-10-09 22:40:13,131] Trial 3 finished with value: 0.05605642597311877 and parameters: {'learning_rate': 0.010568776110697323, 'n_estimators': 1823, 'num_leaves': 30, 'max_depth': 7, 'min_data_in_leaf': 14, 'subsample': 0.8193550001874269, 'colsample_bytree': 0.8803929806111995}. Best is trial 0 with value: 0.056019758941878155.
# [I 2025-10-09 22:42:18,101] Trial 4 finished with value: 0.056139649601209755 and parameters: {'learning_rate': 0.006411092962798134, 'n_estimators': 1639, 'num_leaves': 32, 'max_depth': 7, 'min_data_in_leaf': 14, 'subsample': 0.7715817113880984, 'colsample_bytree': 0.8908717780837565}. Best is trial 0 with value: 0.056019758941878155.
# [I 2025-10-09 22:44:01,754] Trial 5 finished with value: 0.05601379241528495 and parameters: {'learning_rate': 0.017149378264989346, 'n_estimators': 1359, 'num_leaves': 50, 'max_depth': 5, 'min_data_in_leaf': 22, 'subsample': 0.794440531212118, 'colsample_bytree': 0.7048401795905037}. Best is trial 5 with value: 0.05601379241528495.
# [I 2025-10-09 22:45:01,570] Trial 6 finished with value: 0.056710266013115074 and parameters: {'learning_rate': 0.006991271234764776, 'n_estimators': 645, 'num_leaves': 35, 'max_depth': 5, 'min_data_in_leaf': 35, 'subsample': 0.8507205461680108, 'colsample_bytree': 0.7331136132130635}. Best is trial 5 with value: 0.05601379241528495.
# [I 2025-10-09 22:46:33,758] Trial 7 finished with value: 0.055990964531122275 and parameters: {'learning_rate': 0.017380846494677585, 'n_estimators': 1504, 'num_leaves': 35, 'max_depth': 8, 'min_data_in_leaf': 37, 'subsample': 0.7906827184992916, 'colsample_bytree': 0.736900517308947}. Best is trial 7 with value: 0.055990964531122275.
# [I 2025-10-09 22:47:16,639] Trial 8 finished with value: 0.05676366307270685 and parameters: {'learning_rate': 0.006899034696230023, 'n_estimators': 561, 'num_leaves': 34, 'max_depth': 8, 'min_data_in_leaf': 34, 'subsample': 0.8487072255454807, 'colsample_bytree': 0.8972703384066099}. Best is trial 7 with value: 0.055990964531122275.
# [I 2025-10-09 22:47:33,233] Trial 9 finished with value: 0.05693843719933904 and parameters: {'learning_rate': 0.005157533502309654, 'n_estimators': 790, 'num_leaves': 47, 'max_depth': 5, 'min_data_in_leaf': 14, 'subsample': 0.7069380557432058, 'colsample_bytree': 0.722138645816513}. Best is trial 7 with value: 0.055990964531122275.
# [I 2025-10-09 22:47:56,551] A new study created in memory with name: no-name-cc1dbdd6-6415-4e46-9bc1-73f157182abb
# [I 2025-10-09 22:47:56,557] Trial 0 finished with value: inf and parameters: {'learning_rate': 0.008402313541346209, 'n_estimators': 1118, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.8634631795962503, 'colsample_bytree': 0.8149827565178316}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:47:56,560] Trial 1 finished with value: inf and parameters: {'learning_rate': 0.005665710269364928, 'n_estimators': 1360, 'max_depth': 4, 'min_child_weight': 3, 'subsample': 0.846865510049515, 'colsample_bytree': 0.8395403762882586}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:47:56,564] Trial 2 finished with value: inf and parameters: {'learning_rate': 0.0054869433787880575, 'n_estimators': 1183, 'max_depth': 7, 'min_child_weight': 1, 'subsample': 0.894128085204146, 'colsample_bytree': 0.8645168875529842}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:47:56,567] Trial 3 finished with value: inf and parameters: {'learning_rate': 0.00819913570965737, 'n_estimators': 614, 'max_depth': 3, 'min_child_weight': 4, 'subsample': 0.9196066185118572, 'colsample_bytree': 0.8090577032395257}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:47:56,571] Trial 4 finished with value: inf and parameters: {'learning_rate': 0.017295987704498424, 'n_estimators': 1273, 'max_depth': 7, 'min_child_weight': 4, 'subsample': 0.8004038235835627, 'colsample_bytree': 0.8279970458698331}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:47:56,575] Trial 5 finished with value: inf and parameters: {'learning_rate': 0.013654204729457421, 'n_estimators': 597, 'max_depth': 5, 'min_child_weight': 3, 'subsample': 0.8742138475998418, 'colsample_bytree': 0.8753173842431382}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:47:56,578] Trial 6 finished with value: inf and parameters: {'learning_rate': 0.014552128805123691, 'n_estimators': 1324, 'max_depth': 8, 'min_child_weight': 4, 'subsample': 0.9156344468518919, 'colsample_bytree': 0.9346059362604195}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:47:56,581] Trial 7 finished with value: inf and parameters: {'learning_rate': 0.016123647876160236, 'n_estimators': 1459, 'max_depth': 6, 'min_child_weight': 2, 'subsample': 0.8357625559640749, 'colsample_bytree': 0.89630411381224}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:47:56,585] Trial 8 finished with value: inf and parameters: {'learning_rate': 0.011104817450434172, 'n_estimators': 821, 'max_depth': 4, 'min_child_weight': 2, 'subsample': 0.9058732572941051, 'colsample_bytree': 0.84239607662573}. Best is trial 0 with value: inf.
# [I 2025-10-09 22:47:56,589] Trial 9 finished with value: inf and parameters: {'learning_rate': 0.016528201477047307, 'n_estimators': 1060, 'max_depth': 6, 'min_child_weight': 5, 'subsample': 0.8851631122970876, 'colsample_bytree': 0.8050413490960262}. Best is trial 0 with value: inf.
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# XGBoost trial failed: XGBModel.fit() got an unexpected keyword argument 'callbacks'
# Warning: XGBoost early stopping not supported. Training without early stopping.
# Fold 5 RMSE (ensemble): 0.05591 with weights (0.6, 0.4)
# Fold 5 RMSE (LightGBM only): 0.05599
# Ensemble test predictions min: 0.027, max: 0.870, mean: 0.352
# LightGBM-only test predictions min: 0.024, max: 0.874, mean: 0.352
# Mean CV RMSE (ensemble): 0.05609 ± 0.00014
# Mean CV RMSE (LightGBM only): 0.05612 ± 0.00011
# Best ensemble weights: (0.6, 0.4)
# Low-importance features: ['school_season', 'bad_weather', 'poor_lighting', 'rush_hour']
# OOF predictions saved as oof_preds_lgbm_xgb_v21.csv
# Ensemble submission saved as submission_lgbm_xgb_v21.csv at 2025-10-09 22:48:38
# Ensemble submission summary:
#                   id  accident_risk
# count  172585.000000  172585.000000
# mean   604046.000000       0.351687
# std     49821.142441       0.156575
# min    517754.000000       0.027063
# 25%    560900.000000       0.242173
# 50%    604046.000000       0.337449
# 75%    647192.000000       0.453722
# max    690338.000000       0.869602
# Ensemble submission preview (first 10 rows):
#        id  accident_risk
# 0  517754       0.297030
# 1  517755       0.122748
# 2  517756       0.184948
# 3  517757       0.317731
# 4  517758       0.401325
# 5  517759       0.464547
# 6  517760       0.258481
# 7  517761       0.198697
# 8  517762       0.368208
# 9  517763       0.322633
# LightGBM-only submission saved as submission_lgbm_v21.csv at 2025-10-09 22:48:39
# LightGBM-only submission summary:
#                   id  accident_risk
# count  172585.000000  172585.000000
# mean   604046.000000       0.351690
# std     49821.142441       0.156704
# min    517754.000000       0.024134
# 25%    560900.000000       0.242111
# 50%    604046.000000       0.337534
# 75%    647192.000000       0.453988
# max    690338.000000       0.873941
# LightGBM-only submission preview (first 10 rows):
#        id  accident_risk
# 0  517754       0.296501
# 1  517755       0.123300
# 2  517756       0.185474
# 3  517757       0.316299
# 4  517758       0.400315
# 5  517759       0.465254
# 6  517760       0.258112
# 7  517761       0.198773
# 8  517762       0.369137
# 9  517763       0.321904
# submission_lgbm_xgb_v21.csv size: 4617.75 KB
# submission_lgbm_xgb_v21.csv MD5 hash: b1b19febba175d6c61382517cb7b4c34
# submission_lgbm_v21.csv size: 4617.24 KB
# submission_lgbm_v21.csv MD5 hash: 242f862645018aec1b1549428643563b
# oof_preds_lgbm_xgb_v21.csv size: 23550.90 KB
# oof_preds_lgbm_xgb_v21.csv MD5 hash: 4cca344f09dca622be34c517865e276c
# Raw test predictions saved as raw_test_preds_lgbm_xgb_v21.csv

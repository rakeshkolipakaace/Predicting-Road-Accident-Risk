# %%
# Install required libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
import lightgbm as lgb
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import optuna
import warnings
warnings.filterwarnings('ignore')

# For reproducibility
np.random.seed(42)

# Load data
try:
    train = pd.read_csv('train.csv')
    test = pd.read_csv('test.csv')
    sample = pd.read_csv('sample_submission.csv')
except FileNotFoundError:
    print("Error: Ensure train.csv, test.csv, and sample_submission.csv are in the working directory.")
    exit()

print(f'Train shape: {train.shape}')
print(f'Test shape: {test.shape}')
print(f'Sample shape: {sample.shape}')
print(f'Train columns: {train.columns.tolist()}')
print('Column data types:')
print(train.dtypes)

# Check for missing values
print('Missing values in train:')
print(train.isnull().sum())
print('Missing values in test:')
print(test.isnull().sum())

# Check target skewness
y = train['accident_risk']
print(f'Target skewness: {y.skew():.3f}')
plt.hist(y, bins=30)
plt.title('Distribution of accident_risk')
plt.show()

# Validate columns
required_cols = ['id', 'accident_risk', 'speed_limit', 'curvature', 'road_type', 
                 'lighting', 'weather', 'time_of_day', 'road_signs_present', 
                 'public_road', 'holiday', 'school_season']
missing_cols = [col for col in required_cols if col not in train.columns]
if missing_cols:
    print(f"Error: Missing columns in train: {missing_cols}")
    exit()

# Preprocessing
# Drop id
train_id = train['id']
test_id = test['id']
train = train.drop('id', axis=1)
test = test.drop('id', axis=1)

# Target (log-transform if skewed)
use_log_transform = y.skew() > 1 or y.skew() < -1
if use_log_transform:
    print('Applying log1p transformation to target due to skewness.')
    y = np.log1p(y)

train = train.drop('accident_risk', axis=1)

# Combine for preprocessing
all_data = pd.concat([train, test], axis=0, ignore_index=True)

# Feature engineering
all_data['speed_curv_interact'] = all_data['speed_limit'] * all_data['curvature']
all_data['bad_weather'] = np.where(all_data['weather'].isin(['rainy', 'foggy']), 1, 0)
all_data['poor_lighting'] = np.where(all_data['lighting'].isin(['dim', 'night']), 1, 0)
all_data['rush_hour'] = np.where(all_data['time_of_day'].isin(['morning', 'evening']), 1, 0)
all_data['road_condition'] = all_data['curvature'] * all_data['bad_weather']
all_data['holiday_rush'] = all_data['holiday'] * all_data['rush_hour']
all_data['speed_limit_sq'] = all_data['speed_limit'] ** 2
all_data['speed_poor_lighting'] = all_data['speed_limit'] * all_data['poor_lighting']
all_data['curvature_sq'] = all_data['curvature'] ** 2
all_data['speed_rush_hour'] = all_data['speed_limit'] * all_data['rush_hour']
all_data['curvature_poor_lighting'] = all_data['curvature'] * all_data['poor_lighting']
# New feature
all_data['weather_rush_hour'] = all_data['bad_weather'] * all_data['rush_hour']

# Encode categoricals
cat_cols = ['road_type', 'lighting', 'weather', 'time_of_day']
label_encoders = {}
for col in cat_cols:
    all_data[col] = all_data[col].astype(str)  # Ensure string type
    le = LabelEncoder()
    all_data[col] = le.fit_transform(all_data[col])
    label_encoders[col] = le

# Boolean cols to int
bool_cols = ['road_signs_present', 'public_road', 'holiday', 'school_season']
for col in bool_cols:
    all_data[col] = all_data[col].astype(int)

# Handle outliers
num_cols = ['speed_limit', 'curvature', 'speed_curv_interact', 'road_condition', 
            'speed_limit_sq', 'speed_poor_lighting', 'curvature_sq', 'speed_rush_hour',
            'curvature_poor_lighting', 'weather_rush_hour']
for col in num_cols:
    upper_limit = all_data[col].quantile(0.99)
    all_data[col] = np.clip(all_data[col], None, upper_limit)

# Split back
train = all_data[:len(train)].reset_index(drop=True)
test = all_data[len(train):].reset_index(drop=True)

# Prepare X
X = train
X_test = test

print('Preprocessing complete.')

# Optuna objective for LightGBM
def objective(trial, X_train, y_train, X_val, y_val, use_log_transform):
    params = {
        'objective': 'regression',
        'metric': 'rmse',
        'verbosity': -1,
        'n_jobs': -1,
        'random_state': 42,
        'learning_rate': trial.suggest_float('learning_rate', 0.005, 0.05, log=True),
        'n_estimators': trial.suggest_int('n_estimators', 1000, 5000),
        'num_leaves': trial.suggest_int('num_leaves', 20, 80),
        'max_depth': trial.suggest_int('max_depth', 5, 12),
        'min_data_in_leaf': trial.suggest_int('min_data_in_leaf', 10, 50),
        'subsample': trial.suggest_float('subsample', 0.6, 0.9),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 0.9)
    }
    model = lgb.LGBMRegressor(**params)
    model.fit(
        X_train, y_train,
        eval_set=[(X_val, y_val)],
        eval_metric='rmse',
        callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=False)]
    )
    y_pred = model.predict(X_val)
    if use_log_transform:
        y_pred = np.expm1(y_pred)
        y_val = np.expm1(y_val)
    return np.sqrt(mean_squared_error(y_val, y_pred))

# Cross-validation setup
kf = KFold(n_splits=5, shuffle=True, random_state=42)
lgbm_preds = np.zeros(len(X_test))
rf_preds = np.zeros(len(X_test))
val_rmse = []

# Model parameters
rf_params = {
    'n_estimators': 500,
    'max_depth': 10,
    'min_samples_split': 5,
    'min_samples_leaf': 2,
    'n_jobs': -1,
    'random_state': 42
}

# Ensemble weight tuning
weight_combinations = [
    (0.7, 0.3),  # lgbm, rf
    (0.8, 0.2),
    (0.6, 0.4),
    (0.9, 0.1)
]

best_weights = None
best_val_rmse = float('inf')

# Cross-validation loop
for fold, (train_idx, val_idx) in enumerate(kf.split(X)):
    print(f'Training fold {fold + 1}...')
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
    
    # LightGBM with Optuna
    study = optuna.create_study(direction='minimize')
    study.optimize(lambda trial: objective(trial, X_train, y_train, X_val, y_val, use_log_transform), n_trials=15)
    lgbm_params = study.best_params
    lgbm_params.update({
        'objective': 'regression',
        'metric': 'rmse',
        'verbosity': -1,
        'n_jobs': -1,
        'random_state': 42
    })
    lgbm_model = lgb.LGBMRegressor(**lgbm_params)
    lgbm_model.fit(
        X_train, y_train,
        eval_set=[(X_val, y_val)],
        eval_metric='rmse',
        callbacks=[lgb.early_stopping(stopping_rounds=100, verbose=False)]
    )
    
    # Random Forest
    rf_model = RandomForestRegressor(**rf_params)
    rf_model.fit(X_train, y_train)
    
    # Validation predictions
    lgbm_val_pred = lgbm_model.predict(X_val)
    rf_val_pred = rf_model.predict(X_val)
    
    # Tune ensemble weights
    fold_best_rmse = float('inf')
    fold_best_weights = None
    for w_lgbm, w_rf in weight_combinations:
        val_pred = w_lgbm * lgbm_val_pred + w_rf * rf_val_pred
        if use_log_transform:
            val_pred = np.expm1(val_pred)
            y_val_temp = np.expm1(y_val)
        else:
            y_val_temp = y_val
        rmse = np.sqrt(mean_squared_error(y_val_temp, val_pred))
        if rmse < fold_best_rmse:
            fold_best_rmse = rmse
            fold_best_weights = (w_lgbm, w_rf)
    
    val_rmse.append(fold_best_rmse)
    print(f'Fold {fold + 1} RMSE: {fold_best_rmse:.5f} with weights {fold_best_weights}')
    
    # Test predictions with best weights for this fold
    lgbm_preds += lgbm_model.predict(X_test) * fold_best_weights[0] / kf.n_splits
    rf_preds += rf_model.predict(X_test) * fold_best_weights[1] / kf.n_splits
    
    # Update global best weights
    if fold_best_rmse < best_val_rmse:
        best_val_rmse = fold_best_rmse
        best_weights = fold_best_weights

# Stack test predictions
test_preds = best_weights[0] * lgbm_preds + best_weights[1] * rf_preds
if use_log_transform:
    test_preds = np.expm1(test_preds)

# Ensure predictions are between 0 and 1
test_preds = np.clip(test_preds, 0.01, 0.99)

print(f'Mean CV RMSE: {np.mean(val_rmse):.5f} ± {np.std(val_rmse):.5f}')
print(f'Best ensemble weights: {best_weights}')

# Feature importance (from last LightGBM model)
lgb.plot_importance(lgbm_model, max_num_features=10)
plt.title('LightGBM Feature Importance')
plt.show()

# Feature selection: Identify low-importance features
importances = pd.Series(lgbm_model.feature_importances_, index=X.columns)
low_importance = importances[importances < importances.mean() * 0.5].index.tolist()
print(f'Low-importance features: {low_importance}')

# Submission
submission = pd.DataFrame({'id': test_id, 'accident_risk': test_preds})
submission.to_csv('submission_lgbm_rf_ensemble.csv', index=False)
print('Submission saved as submission_lgbm_rf_ensemble.csv')
print(submission.head())
# Out:
# Train shape: (517754, 14)
# Test shape: (172585, 13)
# Sample shape: (172585, 2)
# Train columns: ['id', 'road_type', 'num_lanes', 'curvature', 'speed_limit', 'lighting', 'weather', 'road_signs_present', 'public_road', 'time_of_day', 'holiday', 'school_season', 'num_reported_accidents', 'accident_risk']
# Column data types:
# id                          int64
# road_type                  object
# num_lanes                   int64
# curvature                 float64
# speed_limit                 int64
# lighting                   object
# weather                    object
# road_signs_present           bool
# public_road                  bool
# time_of_day                object
# holiday                      bool
# school_season                bool
# num_reported_accidents      int64
# accident_risk             float64
# dtype: object
# Missing values in train:
# id                        0
# road_type                 0
# num_lanes                 0
# curvature                 0
# speed_limit               0
# lighting                  0
# weather                   0
# road_signs_present        0
# public_road               0
# time_of_day               0
# holiday                   0
# school_season             0
# num_reported_accidents    0
# accident_risk             0
# dtype: int64
# Missing values in test:
# id                        0
# road_type                 0
# num_lanes                 0
# curvature                 0
# speed_limit               0
# lighting                  0
# weather                   0
# road_signs_present        0
# public_road               0
# time_of_day               0
# holiday                   0
# school_season             0
# num_reported_accidents    0
# dtype: int64
# Target skewness: 0.378
# [I 2025-10-06 00:30:50,361] A new study created in memory with name: no-name-be9255f6-f807-49ce-ad3b-36bb2dcbc917
# Preprocessing complete.
# Training fold 1...
# [I 2025-10-06 00:34:27,549] Trial 0 finished with value: 0.05621965289263299 and parameters: {'learning_rate': 0.00822443891681636, 'n_estimators': 3154, 'num_leaves': 51, 'max_depth': 9, 'min_data_in_leaf': 20, 'subsample': 0.7526942516529039, 'colsample_bytree': 0.7526113790763619}. Best is trial 0 with value: 0.05621965289263299.
# [I 2025-10-06 00:35:32,667] Trial 1 finished with value: 0.056255824592695985 and parameters: {'learning_rate': 0.005576089399531219, 'n_estimators': 2783, 'num_leaves': 65, 'max_depth': 6, 'min_data_in_leaf': 40, 'subsample': 0.7056933310653953, 'colsample_bytree': 0.88143734331395}. Best is trial 0 with value: 0.05621965289263299.
# [I 2025-10-06 00:35:58,220] Trial 2 finished with value: 0.056245018846544564 and parameters: {'learning_rate': 0.017111883669133406, 'n_estimators': 3501, 'num_leaves': 71, 'max_depth': 6, 'min_data_in_leaf': 41, 'subsample': 0.7550837970425012, 'colsample_bytree': 0.7840464855820656}. Best is trial 0 with value: 0.05621965289263299.
# [I 2025-10-06 00:36:38,546] Trial 3 finished with value: 0.05624318521777525 and parameters: {'learning_rate': 0.00924654119960128, 'n_estimators': 2335, 'num_leaves': 66, 'max_depth': 8, 'min_data_in_leaf': 43, 'subsample': 0.8733898816155643, 'colsample_bytree': 0.7976939275698662}. Best is trial 0 with value: 0.05621965289263299.
# [I 2025-10-06 00:36:59,262] Trial 4 finished with value: 0.056246132113941895 and parameters: {'learning_rate': 0.017869693910052463, 'n_estimators': 1180, 'num_leaves': 59, 'max_depth': 7, 'min_data_in_leaf': 13, 'subsample': 0.6167606684008712, 'colsample_bytree': 0.7268987120704347}. Best is trial 0 with value: 0.05621965289263299.
# [I 2025-10-06 00:37:12,492] Trial 5 finished with value: 0.05623521674191241 and parameters: {'learning_rate': 0.03400221231197126, 'n_estimators': 4355, 'num_leaves': 78, 'max_depth': 6, 'min_data_in_leaf': 49, 'subsample': 0.7564451974519787, 'colsample_bytree': 0.8480981965442693}. Best is trial 0 with value: 0.05621965289263299.
# [I 2025-10-06 00:37:30,414] Trial 6 finished with value: 0.056236177613957536 and parameters: {'learning_rate': 0.04759531860052284, 'n_estimators': 4077, 'num_leaves': 26, 'max_depth': 11, 'min_data_in_leaf': 17, 'subsample': 0.8180562057646635, 'colsample_bytree': 0.6078387888055078}. Best is trial 0 with value: 0.05621965289263299.
# [I 2025-10-06 00:37:54,590] Trial 7 finished with value: 0.05625599881954774 and parameters: {'learning_rate': 0.022657347714762053, 'n_estimators': 2211, 'num_leaves': 27, 'max_depth': 12, 'min_data_in_leaf': 49, 'subsample': 0.6611062352491158, 'colsample_bytree': 0.719339320947816}. Best is trial 0 with value: 0.05621965289263299.
# [I 2025-10-06 00:38:16,245] Trial 8 finished with value: 0.05650695231807105 and parameters: {'learning_rate': 0.007140593553298097, 'n_estimators': 1588, 'num_leaves': 20, 'max_depth': 6, 'min_data_in_leaf': 20, 'subsample': 0.7704924713909422, 'colsample_bytree': 0.7209349997889687}. Best is trial 0 with value: 0.05621965289263299.
# [I 2025-10-06 00:38:30,332] Trial 9 finished with value: 0.05624391115940927 and parameters: {'learning_rate': 0.047085889873711664, 'n_estimators': 4873, 'num_leaves': 67, 'max_depth': 6, 'min_data_in_leaf': 28, 'subsample': 0.7394996268336012, 'colsample_bytree': 0.6411659445563987}. Best is trial 0 with value: 0.05621965289263299.
# [I 2025-10-06 00:39:16,482] Trial 10 finished with value: 0.056251081568203444 and parameters: {'learning_rate': 0.010553854722254513, 'n_estimators': 3437, 'num_leaves': 44, 'max_depth': 10, 'min_data_in_leaf': 27, 'subsample': 0.8983873655890032, 'colsample_bytree': 0.6660993917835767}. Best is trial 0 with value: 0.05621965289263299.
# [I 2025-10-06 00:39:32,734] Trial 11 finished with value: 0.05624256825824313 and parameters: {'learning_rate': 0.029032442124412958, 'n_estimators': 4949, 'num_leaves': 80, 'max_depth': 9, 'min_data_in_leaf': 23, 'subsample': 0.8140784478362885, 'colsample_bytree': 0.8735060669945155}. Best is trial 0 with value: 0.05621965289263299.
# [I 2025-10-06 00:40:14,073] Trial 12 finished with value: 0.05622042579373094 and parameters: {'learning_rate': 0.011599965802998309, 'n_estimators': 4253, 'num_leaves': 47, 'max_depth': 8, 'min_data_in_leaf': 34, 'subsample': 0.7043855512194667, 'colsample_bytree': 0.8180233774738012}. Best is trial 0 with value: 0.05621965289263299.
# [I 2025-10-06 00:40:57,031] Trial 13 finished with value: 0.05622077279402066 and parameters: {'learning_rate': 0.01204837818492643, 'n_estimators': 3836, 'num_leaves': 46, 'max_depth': 8, 'min_data_in_leaf': 36, 'subsample': 0.6817117752607624, 'colsample_bytree': 0.8147489065605361}. Best is trial 0 with value: 0.05621965289263299.
# [I 2025-10-06 00:41:40,313] Trial 14 finished with value: 0.05627464815267861 and parameters: {'learning_rate': 0.007508390934645063, 'n_estimators': 2871, 'num_leaves': 39, 'max_depth': 9, 'min_data_in_leaf': 33, 'subsample': 0.6358998665640502, 'colsample_bytree': 0.7616393625073626}. Best is trial 0 with value: 0.05621965289263299.
# Fold 1 RMSE: 0.05620 with weights (0.7, 0.3)
# [I 2025-10-06 00:45:11,906] A new study created in memory with name: no-name-9af9752c-e069-436c-af4b-de61d18d8ce2
# Training fold 2...
# [I 2025-10-06 00:45:28,222] Trial 0 finished with value: 0.056103499088378084 and parameters: {'learning_rate': 0.04028430836549047, 'n_estimators': 3987, 'num_leaves': 60, 'max_depth': 10, 'min_data_in_leaf': 44, 'subsample': 0.7239412521349934, 'colsample_bytree': 0.7859066795159907}. Best is trial 0 with value: 0.056103499088378084.
# [I 2025-10-06 00:46:44,571] Trial 1 finished with value: 0.056076310708233795 and parameters: {'learning_rate': 0.014295930964890327, 'n_estimators': 1834, 'num_leaves': 69, 'max_depth': 6, 'min_data_in_leaf': 19, 'subsample': 0.6602012850683726, 'colsample_bytree': 0.6319999175405103}. Best is trial 1 with value: 0.056076310708233795.
# [I 2025-10-06 00:49:13,919] Trial 2 finished with value: 0.05612284005356068 and parameters: {'learning_rate': 0.01151888150482003, 'n_estimators': 2753, 'num_leaves': 32, 'max_depth': 11, 'min_data_in_leaf': 30, 'subsample': 0.6099359366217524, 'colsample_bytree': 0.7758536677665637}. Best is trial 1 with value: 0.056076310708233795.
# [I 2025-10-06 00:51:01,883] Trial 3 finished with value: 0.05609860117072395 and parameters: {'learning_rate': 0.028416583250081867, 'n_estimators': 3809, 'num_leaves': 59, 'max_depth': 5, 'min_data_in_leaf': 24, 'subsample': 0.8622572873482077, 'colsample_bytree': 0.7773294790185575}. Best is trial 1 with value: 0.056076310708233795.
# [I 2025-10-06 00:52:17,812] Trial 4 finished with value: 0.056079026999817615 and parameters: {'learning_rate': 0.03298152619199126, 'n_estimators': 4336, 'num_leaves': 64, 'max_depth': 6, 'min_data_in_leaf': 17, 'subsample': 0.8444365958154816, 'colsample_bytree': 0.6206247620739717}. Best is trial 1 with value: 0.056076310708233795.
# [I 2025-10-06 00:56:01,459] Trial 5 finished with value: 0.0561364469393033 and parameters: {'learning_rate': 0.00664394087053469, 'n_estimators': 3912, 'num_leaves': 33, 'max_depth': 8, 'min_data_in_leaf': 47, 'subsample': 0.6554056971663025, 'colsample_bytree': 0.7688227166455538}. Best is trial 1 with value: 0.056076310708233795.
# [I 2025-10-06 00:59:57,590] Trial 6 finished with value: 0.056089669815266516 and parameters: {'learning_rate': 0.008876379324748654, 'n_estimators': 3376, 'num_leaves': 55, 'max_depth': 7, 'min_data_in_leaf': 36, 'subsample': 0.7545903527683184, 'colsample_bytree': 0.6672779592303698}. Best is trial 1 with value: 0.056076310708233795.
# [I 2025-10-06 01:01:30,413] Trial 7 finished with value: 0.056104217302752085 and parameters: {'learning_rate': 0.014311891904136596, 'n_estimators': 4643, 'num_leaves': 59, 'max_depth': 5, 'min_data_in_leaf': 13, 'subsample': 0.7854523893273146, 'colsample_bytree': 0.6829953842765538}. Best is trial 1 with value: 0.056076310708233795.
# [I 2025-10-06 01:01:47,523] Trial 8 finished with value: 0.05610177631015378 and parameters: {'learning_rate': 0.04832727965544543, 'n_estimators': 3106, 'num_leaves': 74, 'max_depth': 5, 'min_data_in_leaf': 14, 'subsample': 0.7051097743958724, 'colsample_bytree': 0.627054142468585}. Best is trial 1 with value: 0.056076310708233795.
# [I 2025-10-06 01:02:33,234] Trial 9 finished with value: 0.05612865458595571 and parameters: {'learning_rate': 0.0058731850354231665, 'n_estimators': 3155, 'num_leaves': 39, 'max_depth': 10, 'min_data_in_leaf': 27, 'subsample': 0.8106829255938741, 'colsample_bytree': 0.8342250917176699}. Best is trial 1 with value: 0.056076310708233795.
# [I 2025-10-06 01:02:48,641] Trial 10 finished with value: 0.05607570694032834 and parameters: {'learning_rate': 0.021508831438382874, 'n_estimators': 1441, 'num_leaves': 79, 'max_depth': 8, 'min_data_in_leaf': 22, 'subsample': 0.666560595931033, 'colsample_bytree': 0.897521638698417}. Best is trial 10 with value: 0.05607570694032834.
# [I 2025-10-06 01:03:07,292] Trial 11 finished with value: 0.05607684996559945 and parameters: {'learning_rate': 0.021428503841546008, 'n_estimators': 1384, 'num_leaves': 80, 'max_depth': 8, 'min_data_in_leaf': 21, 'subsample': 0.6496432624662624, 'colsample_bytree': 0.8660827457593008}. Best is trial 10 with value: 0.05607570694032834.
# [I 2025-10-06 01:03:27,114] Trial 12 finished with value: 0.05604484214980677 and parameters: {'learning_rate': 0.02290693916078043, 'n_estimators': 1230, 'num_leaves': 70, 'max_depth': 7, 'min_data_in_leaf': 10, 'subsample': 0.6766454608982905, 'colsample_bytree': 0.7098838593302514}. Best is trial 12 with value: 0.05604484214980677.
# [I 2025-10-06 01:03:43,127] Trial 13 finished with value: 0.05611032109362705 and parameters: {'learning_rate': 0.021719471805490206, 'n_estimators': 1097, 'num_leaves': 45, 'max_depth': 9, 'min_data_in_leaf': 10, 'subsample': 0.6020917142012067, 'colsample_bytree': 0.7193681786337933}. Best is trial 12 with value: 0.05604484214980677.
# [I 2025-10-06 01:04:05,622] Trial 14 finished with value: 0.056149593953926005 and parameters: {'learning_rate': 0.020235465156446513, 'n_estimators': 2229, 'num_leaves': 20, 'max_depth': 7, 'min_data_in_leaf': 33, 'subsample': 0.6925001132818256, 'colsample_bytree': 0.8971961358182187}. Best is trial 12 with value: 0.05604484214980677.
# Fold 2 RMSE: 0.05603 with weights (0.8, 0.2)
# [I 2025-10-06 01:10:26,845] A new study created in memory with name: no-name-8d686c13-757f-4ddd-8e83-435504842a5f
# Training fold 3...
# [I 2025-10-06 01:13:53,496] Trial 0 finished with value: 0.05613625584949704 and parameters: {'learning_rate': 0.0078037685924669635, 'n_estimators': 3788, 'num_leaves': 59, 'max_depth': 9, 'min_data_in_leaf': 14, 'subsample': 0.6959092452510449, 'colsample_bytree': 0.7248738996452211}. Best is trial 0 with value: 0.05613625584949704.
# [I 2025-10-06 01:16:11,021] Trial 1 finished with value: 0.056336435612531155 and parameters: {'learning_rate': 0.0053065252158665, 'n_estimators': 1897, 'num_leaves': 26, 'max_depth': 9, 'min_data_in_leaf': 40, 'subsample': 0.8876370570805464, 'colsample_bytree': 0.794405460159331}. Best is trial 0 with value: 0.05613625584949704.
# [I 2025-10-06 01:17:48,270] Trial 2 finished with value: 0.05617656798775875 and parameters: {'learning_rate': 0.009456116874516014, 'n_estimators': 3898, 'num_leaves': 46, 'max_depth': 5, 'min_data_in_leaf': 29, 'subsample': 0.7022140597827933, 'colsample_bytree': 0.6211033785170332}. Best is trial 0 with value: 0.05613625584949704.
# [I 2025-10-06 01:18:13,648] Trial 3 finished with value: 0.05613508865070366 and parameters: {'learning_rate': 0.016005479632924993, 'n_estimators': 2465, 'num_leaves': 80, 'max_depth': 11, 'min_data_in_leaf': 46, 'subsample': 0.6733609325273708, 'colsample_bytree': 0.7204572717754799}. Best is trial 3 with value: 0.05613508865070366.
# [I 2025-10-06 01:18:38,525] Trial 4 finished with value: 0.05617573120157781 and parameters: {'learning_rate': 0.03215503749500181, 'n_estimators': 2124, 'num_leaves': 34, 'max_depth': 5, 'min_data_in_leaf': 37, 'subsample': 0.7655902413620568, 'colsample_bytree': 0.8300771412302189}. Best is trial 3 with value: 0.05613508865070366.
# [I 2025-10-06 01:20:22,636] Trial 5 finished with value: 0.05620929894261952 and parameters: {'learning_rate': 0.0075671548151522465, 'n_estimators': 4087, 'num_leaves': 44, 'max_depth': 5, 'min_data_in_leaf': 41, 'subsample': 0.8167815805792035, 'colsample_bytree': 0.736745199561011}. Best is trial 3 with value: 0.05613508865070366.
# [I 2025-10-06 01:21:26,455] Trial 6 finished with value: 0.05619854042391511 and parameters: {'learning_rate': 0.030632464188419056, 'n_estimators': 3098, 'num_leaves': 25, 'max_depth': 7, 'min_data_in_leaf': 34, 'subsample': 0.6677776422532025, 'colsample_bytree': 0.8993051884197161}. Best is trial 3 with value: 0.05613508865070366.
# [I 2025-10-06 01:22:39,905] Trial 7 finished with value: 0.056145852083476604 and parameters: {'learning_rate': 0.01631019703443764, 'n_estimators': 2339, 'num_leaves': 71, 'max_depth': 6, 'min_data_in_leaf': 32, 'subsample': 0.71516756359574, 'colsample_bytree': 0.7840306129763601}. Best is trial 3 with value: 0.05613508865070366.
# [I 2025-10-06 01:23:46,104] Trial 8 finished with value: 0.05615544065086036 and parameters: {'learning_rate': 0.00771804979323595, 'n_estimators': 3812, 'num_leaves': 32, 'max_depth': 9, 'min_data_in_leaf': 41, 'subsample': 0.8896484772861404, 'colsample_bytree': 0.6185274849932415}. Best is trial 3 with value: 0.05613508865070366.
# [I 2025-10-06 01:24:45,959] Trial 9 finished with value: 0.05614293879312691 and parameters: {'learning_rate': 0.007749446718062377, 'n_estimators': 4482, 'num_leaves': 68, 'max_depth': 9, 'min_data_in_leaf': 50, 'subsample': 0.8432810048416813, 'colsample_bytree': 0.6161229323654615}. Best is trial 3 with value: 0.05613508865070366.
# [I 2025-10-06 01:25:08,723] Trial 10 finished with value: 0.056128112323927004 and parameters: {'learning_rate': 0.01788133818316864, 'n_estimators': 1018, 'num_leaves': 80, 'max_depth': 12, 'min_data_in_leaf': 22, 'subsample': 0.6006111231046432, 'colsample_bytree': 0.6822123071780565}. Best is trial 10 with value: 0.056128112323927004.
# [I 2025-10-06 01:25:30,866] Trial 11 finished with value: 0.05613137600347774 and parameters: {'learning_rate': 0.01714976592576364, 'n_estimators': 1099, 'num_leaves': 80, 'max_depth': 12, 'min_data_in_leaf': 21, 'subsample': 0.6033192648113673, 'colsample_bytree': 0.6736412556070795}. Best is trial 10 with value: 0.056128112323927004.
# [I 2025-10-06 01:25:49,696] Trial 12 finished with value: 0.05613382233908219 and parameters: {'learning_rate': 0.02154551118986829, 'n_estimators': 1008, 'num_leaves': 78, 'max_depth': 12, 'min_data_in_leaf': 21, 'subsample': 0.603548702566596, 'colsample_bytree': 0.6826687271547693}. Best is trial 10 with value: 0.056128112323927004.
# [I 2025-10-06 01:25:59,609] Trial 13 finished with value: 0.05614639091402058 and parameters: {'learning_rate': 0.043667357248949365, 'n_estimators': 1088, 'num_leaves': 60, 'max_depth': 11, 'min_data_in_leaf': 23, 'subsample': 0.6087010347326012, 'colsample_bytree': 0.6691883188775596}. Best is trial 10 with value: 0.056128112323927004.
# [I 2025-10-06 01:26:28,990] Trial 14 finished with value: 0.056138155641950606 and parameters: {'learning_rate': 0.01243377483430069, 'n_estimators': 1492, 'num_leaves': 69, 'max_depth': 12, 'min_data_in_leaf': 12, 'subsample': 0.643703827040784, 'colsample_bytree': 0.6757773072752494}. Best is trial 10 with value: 0.056128112323927004.
# Fold 3 RMSE: 0.05611 with weights (0.7, 0.3)
# [I 2025-10-06 01:29:44,546] A new study created in memory with name: no-name-85b4e168-2ad3-4050-8f4f-97da49e21807
# Training fold 4...
# [I 2025-10-06 01:30:16,920] Trial 0 finished with value: 0.05611323766946152 and parameters: {'learning_rate': 0.006610795260606416, 'n_estimators': 2532, 'num_leaves': 25, 'max_depth': 7, 'min_data_in_leaf': 50, 'subsample': 0.6896330740746385, 'colsample_bytree': 0.813933563294715}. Best is trial 0 with value: 0.05611323766946152.
# [I 2025-10-06 01:30:51,694] Trial 1 finished with value: 0.055980999372063155 and parameters: {'learning_rate': 0.01373923498738063, 'n_estimators': 4610, 'num_leaves': 51, 'max_depth': 9, 'min_data_in_leaf': 28, 'subsample': 0.7614627806771991, 'colsample_bytree': 0.7562764248242589}. Best is trial 1 with value: 0.055980999372063155.
# [I 2025-10-06 01:31:05,589] Trial 2 finished with value: 0.05600632218642032 and parameters: {'learning_rate': 0.02744143747440416, 'n_estimators': 3383, 'num_leaves': 54, 'max_depth': 6, 'min_data_in_leaf': 46, 'subsample': 0.6186865437766219, 'colsample_bytree': 0.8022503270019559}. Best is trial 1 with value: 0.055980999372063155.
# [I 2025-10-06 01:31:24,737] Trial 3 finished with value: 0.05597377738294995 and parameters: {'learning_rate': 0.023349869889874326, 'n_estimators': 1622, 'num_leaves': 63, 'max_depth': 10, 'min_data_in_leaf': 22, 'subsample': 0.7462393751380355, 'colsample_bytree': 0.8852655704025522}. Best is trial 3 with value: 0.05597377738294995.
# [I 2025-10-06 01:31:48,735] Trial 4 finished with value: 0.056111295785799764 and parameters: {'learning_rate': 0.008923086883695707, 'n_estimators': 1769, 'num_leaves': 78, 'max_depth': 5, 'min_data_in_leaf': 39, 'subsample': 0.8931425417733827, 'colsample_bytree': 0.7242948408609753}. Best is trial 3 with value: 0.05597377738294995.
# [I 2025-10-06 01:32:25,368] Trial 5 finished with value: 0.05596347331461425 and parameters: {'learning_rate': 0.010810703689298382, 'n_estimators': 3558, 'num_leaves': 70, 'max_depth': 10, 'min_data_in_leaf': 28, 'subsample': 0.8476482333082662, 'colsample_bytree': 0.7600298385206986}. Best is trial 5 with value: 0.05596347331461425.
# [I 2025-10-06 01:32:38,287] Trial 6 finished with value: 0.05600916188679387 and parameters: {'learning_rate': 0.03318465220688904, 'n_estimators': 4409, 'num_leaves': 44, 'max_depth': 7, 'min_data_in_leaf': 38, 'subsample': 0.607781161925823, 'colsample_bytree': 0.8254846461634457}. Best is trial 5 with value: 0.05596347331461425.
# [I 2025-10-06 01:32:46,171] Trial 7 finished with value: 0.055976067038137504 and parameters: {'learning_rate': 0.048694429059541744, 'n_estimators': 4225, 'num_leaves': 78, 'max_depth': 11, 'min_data_in_leaf': 50, 'subsample': 0.8170146265222022, 'colsample_bytree': 0.7547988403216878}. Best is trial 5 with value: 0.05596347331461425.
# [I 2025-10-06 01:33:15,223] Trial 8 finished with value: 0.056015469579481426 and parameters: {'learning_rate': 0.020311474704876084, 'n_estimators': 3656, 'num_leaves': 21, 'max_depth': 8, 'min_data_in_leaf': 47, 'subsample': 0.7778937053328203, 'colsample_bytree': 0.7460573962725392}. Best is trial 5 with value: 0.05596347331461425.
# [I 2025-10-06 01:33:42,737] Trial 9 finished with value: 0.056042126153737916 and parameters: {'learning_rate': 0.010938775837787405, 'n_estimators': 2142, 'num_leaves': 29, 'max_depth': 7, 'min_data_in_leaf': 37, 'subsample': 0.7742474636854617, 'colsample_bytree': 0.7280305926934302}. Best is trial 5 with value: 0.05596347331461425.
# [I 2025-10-06 01:34:09,281] Trial 10 finished with value: 0.05610624526952034 and parameters: {'learning_rate': 0.00567456746798683, 'n_estimators': 1018, 'num_leaves': 67, 'max_depth': 12, 'min_data_in_leaf': 12, 'subsample': 0.894644412853266, 'colsample_bytree': 0.6308268439328711}. Best is trial 5 with value: 0.05596347331461425.
# [I 2025-10-06 01:34:30,040] Trial 11 finished with value: 0.0559721726982538 and parameters: {'learning_rate': 0.017586823204244338, 'n_estimators': 2991, 'num_leaves': 65, 'max_depth': 10, 'min_data_in_leaf': 22, 'subsample': 0.6937903275909243, 'colsample_bytree': 0.8733155455868719}. Best is trial 5 with value: 0.05596347331461425.
# [I 2025-10-06 01:34:50,436] Trial 12 finished with value: 0.055971686450070904 and parameters: {'learning_rate': 0.015965473654565295, 'n_estimators': 2853, 'num_leaves': 65, 'max_depth': 10, 'min_data_in_leaf': 17, 'subsample': 0.6861421357710493, 'colsample_bytree': 0.891740599142512}. Best is trial 5 with value: 0.05596347331461425.
# [I 2025-10-06 01:35:19,999] Trial 13 finished with value: 0.05597339659328828 and parameters: {'learning_rate': 0.011954097384267165, 'n_estimators': 3812, 'num_leaves': 70, 'max_depth': 12, 'min_data_in_leaf': 10, 'subsample': 0.8404762625005436, 'colsample_bytree': 0.6580408806349117}. Best is trial 5 with value: 0.05596347331461425.
# [I 2025-10-06 01:36:02,513] Trial 14 finished with value: 0.05597226063652067 and parameters: {'learning_rate': 0.009860845757179135, 'n_estimators': 2882, 'num_leaves': 59, 'max_depth': 10, 'min_data_in_leaf': 19, 'subsample': 0.6865121550797766, 'colsample_bytree': 0.6829348055094276}. Best is trial 5 with value: 0.05596347331461425.
# Fold 4 RMSE: 0.05595 with weights (0.7, 0.3)
# [I 2025-10-06 01:39:02,306] A new study created in memory with name: no-name-bd13c859-c385-4950-ac1a-719e1caa0f42
# Training fold 5...
# [I 2025-10-06 01:39:31,978] Trial 0 finished with value: 0.05600056156841596 and parameters: {'learning_rate': 0.010232528969434189, 'n_estimators': 1398, 'num_leaves': 56, 'max_depth': 6, 'min_data_in_leaf': 31, 'subsample': 0.849056784194895, 'colsample_bytree': 0.6024946631918694}. Best is trial 0 with value: 0.05600056156841596.
# [I 2025-10-06 01:39:55,824] Trial 1 finished with value: 0.05596824902744041 and parameters: {'learning_rate': 0.02921495347762381, 'n_estimators': 2066, 'num_leaves': 23, 'max_depth': 7, 'min_data_in_leaf': 45, 'subsample': 0.8532828613281749, 'colsample_bytree': 0.625203162735768}. Best is trial 1 with value: 0.05596824902744041.
# [I 2025-10-06 01:40:27,548] Trial 2 finished with value: 0.05596191506587482 and parameters: {'learning_rate': 0.011547362145398723, 'n_estimators': 3059, 'num_leaves': 72, 'max_depth': 7, 'min_data_in_leaf': 48, 'subsample': 0.8546637303360554, 'colsample_bytree': 0.7796271107890422}. Best is trial 2 with value: 0.05596191506587482.
# [I 2025-10-06 01:41:14,715] Trial 3 finished with value: 0.056064374899333407 and parameters: {'learning_rate': 0.005826231557388637, 'n_estimators': 4032, 'num_leaves': 26, 'max_depth': 9, 'min_data_in_leaf': 45, 'subsample': 0.8808925427377485, 'colsample_bytree': 0.8147134182648565}. Best is trial 2 with value: 0.05596191506587482.
# [I 2025-10-06 01:42:03,692] Trial 4 finished with value: 0.0559374193545252 and parameters: {'learning_rate': 0.007100842126342652, 'n_estimators': 3366, 'num_leaves': 56, 'max_depth': 9, 'min_data_in_leaf': 22, 'subsample': 0.6132100857977758, 'colsample_bytree': 0.7479340924031291}. Best is trial 4 with value: 0.0559374193545252.
# [I 2025-10-06 01:42:44,937] Trial 5 finished with value: 0.05593804562982439 and parameters: {'learning_rate': 0.007538487605772321, 'n_estimators': 3009, 'num_leaves': 76, 'max_depth': 9, 'min_data_in_leaf': 23, 'subsample': 0.6768981975405624, 'colsample_bytree': 0.8199949378845692}. Best is trial 4 with value: 0.0559374193545252.
# [I 2025-10-06 01:43:50,236] Trial 6 finished with value: 0.05596017782484241 and parameters: {'learning_rate': 0.007395651913674806, 'n_estimators': 4887, 'num_leaves': 41, 'max_depth': 11, 'min_data_in_leaf': 22, 'subsample': 0.6629543466597926, 'colsample_bytree': 0.6191518621723182}. Best is trial 4 with value: 0.0559374193545252.
# [I 2025-10-06 01:44:11,127] Trial 7 finished with value: 0.05594870072079059 and parameters: {'learning_rate': 0.02415350384479994, 'n_estimators': 1709, 'num_leaves': 49, 'max_depth': 12, 'min_data_in_leaf': 29, 'subsample': 0.7837890618772178, 'colsample_bytree': 0.7250533645628182}. Best is trial 4 with value: 0.0559374193545252.
# [I 2025-10-06 01:44:31,173] Trial 8 finished with value: 0.05604938181324223 and parameters: {'learning_rate': 0.014732215986960798, 'n_estimators': 1612, 'num_leaves': 67, 'max_depth': 5, 'min_data_in_leaf': 43, 'subsample': 0.6555865263909967, 'colsample_bytree': 0.77348209663012}. Best is trial 4 with value: 0.0559374193545252.
# [I 2025-10-06 01:44:46,600] Trial 9 finished with value: 0.056162803047956386 and parameters: {'learning_rate': 0.010327794197885803, 'n_estimators': 1136, 'num_leaves': 60, 'max_depth': 5, 'min_data_in_leaf': 37, 'subsample': 0.8425833386443033, 'colsample_bytree': 0.7029357322039286}. Best is trial 4 with value: 0.0559374193545252.
# [I 2025-10-06 01:44:58,340] Trial 10 finished with value: 0.05595743153796745 and parameters: {'learning_rate': 0.04462046062700245, 'n_estimators': 3983, 'num_leaves': 40, 'max_depth': 10, 'min_data_in_leaf': 10, 'subsample': 0.6115679499044038, 'colsample_bytree': 0.8869261561006953}. Best is trial 4 with value: 0.0559374193545252.
# [I 2025-10-06 01:45:48,172] Trial 11 finished with value: 0.055943216740701726 and parameters: {'learning_rate': 0.005467870801761742, 'n_estimators': 2761, 'num_leaves': 79, 'max_depth': 9, 'min_data_in_leaf': 19, 'subsample': 0.7104576541697963, 'colsample_bytree': 0.8437977710678597}. Best is trial 4 with value: 0.0559374193545252.
# [I 2025-10-06 01:46:37,521] Trial 12 finished with value: 0.05592796881493197 and parameters: {'learning_rate': 0.007775597223439947, 'n_estimators': 3166, 'num_leaves': 78, 'max_depth': 8, 'min_data_in_leaf': 19, 'subsample': 0.6151767893774799, 'colsample_bytree': 0.6899562450914297}. Best is trial 12 with value: 0.05592796881493197.
# [I 2025-10-06 01:47:23,485] Trial 13 finished with value: 0.05595286687647109 and parameters: {'learning_rate': 0.007735122818129228, 'n_estimators': 3742, 'num_leaves': 64, 'max_depth': 8, 'min_data_in_leaf': 13, 'subsample': 0.6047310705411509, 'colsample_bytree': 0.6709145471326333}. Best is trial 12 with value: 0.05592796881493197.
# [I 2025-10-06 01:47:52,269] Trial 14 finished with value: 0.05594303234343474 and parameters: {'learning_rate': 0.019125074500347714, 'n_estimators': 2479, 'num_leaves': 45, 'max_depth': 8, 'min_data_in_leaf': 16, 'subsample': 0.7628876434855516, 'colsample_bytree': 0.6707369025589491}. Best is trial 12 with value: 0.05592796881493197.
# Fold 5 RMSE: 0.05591 with weights (0.8, 0.2)
# Mean CV RMSE: 0.05604 ± 0.00011
# Best ensemble weights: (0.8, 0.2)
# Low-importance features: ['bad_weather', 'poor_lighting', 'rush_hour', 'holiday_rush', 'speed_limit_sq', 'speed_poor_lighting', 'weather_rush_hour']
# Submission saved as submission_lgbm_rf_ensemble.csv
#        id  accident_risk
# 0  517754       0.190774
# 1  517755       0.078534
# 2  517756       0.118479
# 3  517757       0.203010
# 4  517758       0.261498
